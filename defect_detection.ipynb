# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# Unzip your data
# !unzip /content/drive/MyDrive/defect_data.zip -d /content/defect-detection

# Install YOLOv8
# !pip install ultralytics

# Train
import os
os.chdir('/content/drive/MyDrive/defect-detection')
# Out:
# Mounted at /content/drive
# unzip:  cannot find or open /content/drive/MyDrive/defect_data.zip, /content/drive/MyDrive/defect_data.zip.zip or /content/drive/MyDrive/defect_data.zip.ZIP.
# Collecting ultralytics
#   Downloading ultralytics-8.4.19-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.19-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.19 ultralytics-thop-2.0.18

# %%
import os
labels = os.listdir('/content/drive/MyDrive/defect-detection/data/steel/labels/train')
print(labels[:5])
# Out:
# ['inclusion_86.txt', 'inclusion_44.txt', 'inclusion_89.txt', 'inclusion_65.txt', 'inclusion_56.txt']

# %%
import os
print(os.listdir('/content/drive/MyDrive/defect-detection/data/steel/labels/train')[:5])
# Out:
# ['inclusion_86.txt', 'inclusion_44.txt', 'inclusion_89.txt', 'inclusion_65.txt', 'inclusion_56.txt']

# %%
import os

# Check if labels exist
label_path = '/content/drive/MyDrive/defect-detection/data/steel/labels/train'
files = os.listdir(label_path)
print(f"Total label files: {len(files)}")
print("Sample files:", files[:5])

# Check content of one label file
with open(os.path.join(label_path, files[0])) as f:
    print("Content:", f.read())
# Out:
# Total label files: 1439
# Sample files: ['inclusion_86.txt', 'inclusion_44.txt', 'inclusion_89.txt', 'inclusion_65.txt', 'inclusion_56.txt']
# Content: 1 0.237500 0.215000 0.125000 0.420000
# 1 0.132500 0.345000 0.105000 0.260000
# 1 0.087500 0.712500 0.105000 0.325000
# 1 0.267500 0.835000 0.185000 0.250000
# 1 0.635000 0.327500 0.170000 0.445000

# %%
import os

# Check images
train_images = os.listdir('/content/drive/MyDrive/defect-detection/data/steel/images/train')
print("Sample images:", train_images[:3])

# Check labels
train_labels = os.listdir('/content/drive/MyDrive/defect-detection/data/steel/labels/train')
print("Sample labels:", train_labels[:3])

# Check if names match
img_name = train_images[0].replace('.jpg', '.txt').replace('.png', '.txt')
print(f"\nLooking for: {img_name}")
print(f"Exists in labels: {img_name in train_labels}")
# Out:
# Sample images: ['images']
# Sample labels: ['inclusion_86.txt', 'inclusion_44.txt', 'inclusion_89.txt']
#
# Looking for: images
# Exists in labels: False

# %%
import shutil
import os

src = '/content/drive/MyDrive/defect-detection/data/steel/images/train/images'
dst = '/content/drive/MyDrive/defect-detection/data/steel/images/train'

# Move all files up one level
for file in os.listdir(src):
    shutil.move(os.path.join(src, file), os.path.join(dst, file))

# Remove empty folder
os.rmdir(src)
print("Done ✅")

# Do the same for val
src_val = '/content/drive/MyDrive/defect-detection/data/steel/images/val/images'
dst_val = '/content/drive/MyDrive/defect-detection/data/steel/images/val'

for file in os.listdir(src_val):
    shutil.move(os.path.join(src_val, file), os.path.join(dst_val, file))

os.rmdir(src_val)
print("Val done ✅")
# Out:
# Done ✅
# Val done ✅

# %%
import os

# Check exact contents of images/train
train_path = '/content/drive/MyDrive/defect-detection/data/steel/images/train'
contents = os.listdir(train_path)
print("Images train contents:", contents[:5])
print("Total:", len(contents))

# Check one image name vs one label name
label_path = '/content/drive/MyDrive/defect-detection/data/steel/labels/train'
labels = os.listdir(label_path)
print("\nLabel sample:", labels[0])
print("Image sample:", contents[0])

# Check if they match
img_stem = contents[0].replace('.jpg','').replace('.png','').replace('.bmp','')
lbl_stem = labels[0].replace('.txt','')
print(f"\nImage stem: {img_stem}")
print(f"Label stem: {lbl_stem}")
print(f"Match possible: {img_stem == lbl_stem}")
# Out:
# Images train contents: ['patches', 'rolled-in_scale', 'pitted_surface', 'scratches', 'inclusion']
# Total: 6
#
# Label sample: inclusion_86.txt
# Image sample: patches
#
# Image stem: patches
# Label stem: inclusion_86
# Match possible: False

# %%
import shutil
import os

# Move all images from subfolders to train folder directly
train_path = '/content/drive/MyDrive/defect-detection/data/steel/images/train'

for class_folder in os.listdir(train_path):
    class_path = os.path.join(train_path, class_folder)
    if os.path.isdir(class_path):
        for img_file in os.listdir(class_path):
            shutil.move(os.path.join(class_path, img_file), os.path.join(train_path, img_file))
        os.rmdir(class_path)
        print(f"Moved {class_folder} ✅")

# Do same for val
val_path = '/content/drive/MyDrive/defect-detection/data/steel/images/val'

for class_folder in os.listdir(val_path):
    class_path = os.path.join(val_path, class_folder)
    if os.path.isdir(class_path):
        for img_file in os.listdir(class_path):
            shutil.move(os.path.join(class_path, img_file), os.path.join(val_path, img_file))
        os.rmdir(class_path)
        print(f"Moved val/{class_folder} ✅")

print("\nAll done ✅")
# Out:
# Moved patches ✅
# Moved rolled-in_scale ✅
# Moved pitted_surface ✅
# Moved scratches ✅
# Moved inclusion ✅
# Moved crazing ✅
# Moved val/scratches ✅
# Moved val/rolled-in_scale ✅
# Moved val/pitted_surface ✅
# Moved val/patches ✅
# Moved val/crazing ✅
# Moved val/inclusion ✅
#
# All done ✅

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')  # upgraded from nano to small
results = model.train(
    data='/content/drive/MyDrive/defect-detection/data.yaml',
    epochs=100,              # increased from 50 to 100
    imgsz=640,
    batch=16,
    name='steel_defect_v2',  # new name so it doesn't overwrite v1
    flipud=0.5,
    degrees=10,
    hsv_h=0.02,
    mosaic=1.0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 89.8MB/s 0.2s
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/defect-detection/data.yaml, degrees=10, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.5, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.02, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=steel_defect_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 23.5MB/s 0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.2 ms, read: 0.0±0.0 MB/s, size: 15.2 KB)
# train: Scanning /content/drive/MyDrive/defect-detection/data/steel/labels/train.cache... 1439 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1440/1440 317.9Mit/s 0.0s
# train: /content/drive/MyDrive/defect-detection/data/steel/images/train/crazing_120.jpg: 1 duplicate labels removed
# train: /content/drive/MyDrive/defect-detection/data/steel/images/train/inclusion_62.jpg: 1 duplicate labels removed
# train: /content/drive/MyDrive/defect-detection/data/steel/images/train/patches_198.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 0.0±0.0 MB/s, size: 15.1 KB)
# val: Scanning /content/drive/MyDrive/defect-detection/data/steel/labels/val.cache... 360 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 360/360 9.9Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.76G      1.837      3.287      1.939         67        640: 100% ━━━━━━━━━━━━ 90/90 7.2s/it 10:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.0it/s 6.0s
#                    all        360        854      0.331      0.378      0.351      0.138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.54G      1.723      2.018      1.815         68        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.338      0.308      0.205     0.0734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.54G      1.729      2.013      1.859         71        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854      0.216      0.395      0.235      0.078
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.54G      1.695      1.878      1.812         79        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.413      0.417       0.38      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.54G      1.678      1.864      1.788         58        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854       0.54      0.434       0.42      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.54G      1.648      1.834      1.785         70        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.8s
#                    all        360        854      0.318      0.544      0.419      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.54G      1.606      1.764      1.744         69        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.0s
#                    all        360        854      0.592      0.407       0.43      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.54G      1.583      1.693      1.734         81        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.433      0.505      0.472      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.54G      1.555       1.66      1.698         59        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.1it/s 5.8s
#                    all        360        854      0.425      0.615      0.533      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.54G      1.562      1.673      1.716         86        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 32.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.412      0.638       0.58      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.54G      1.545       1.65      1.703         84        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.2s
#                    all        360        854      0.404      0.551      0.469      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.54G      1.521      1.646      1.698         74        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854       0.73      0.523      0.594      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.54G      1.537      1.638      1.702         84        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.538      0.512      0.484      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.54G      1.526      1.619      1.682         83        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.9s
#                    all        360        854      0.579      0.558      0.577       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.54G      1.471      1.561      1.651         92        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.4s
#                    all        360        854      0.552      0.587      0.611      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.54G      1.493      1.592      1.679         73        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        360        854      0.525      0.632      0.621      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.54G      1.491       1.55      1.661         66        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.3s
#                    all        360        854      0.517       0.56      0.564      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.54G      1.479       1.53      1.653         76        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854       0.59      0.411      0.479      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.54G      1.468      1.556      1.657         48        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.0it/s 5.9s
#                    all        360        854      0.702      0.526      0.603      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.54G      1.496       1.53      1.661         88        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.648      0.565      0.592      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.54G      1.479      1.493      1.645         77        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854      0.495      0.559      0.533      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.54G      1.454      1.499      1.639         63        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854       0.51      0.636      0.622      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.54G      1.427      1.473      1.613         89        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 4.9s
#                    all        360        854      0.664        0.5      0.545      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.54G      1.439      1.489      1.622         72        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.549      0.647       0.64      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.54G      1.461      1.477      1.636         70        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.2s
#                    all        360        854      0.537      0.598      0.617      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.54G      1.445       1.48      1.629         84        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.529      0.635      0.586      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.54G      1.424      1.431      1.604         88        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.0s
#                    all        360        854      0.561      0.594      0.613      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.54G      1.429      1.433      1.617         73        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.5s
#                    all        360        854      0.563       0.58      0.586      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.54G      1.438      1.454      1.628         68        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854       0.56      0.633       0.64      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.54G      1.449      1.453      1.624         78        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        360        854      0.553      0.654      0.663        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.54G      1.405      1.393      1.597         68        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.4s
#                    all        360        854      0.648       0.54      0.618      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.54G      1.418      1.417      1.604         79        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        360        854      0.597      0.649       0.67       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.54G      1.387      1.358      1.576         75        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.735      0.528      0.642      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.54G      1.404      1.359      1.584         72        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.1s
#                    all        360        854      0.568      0.638      0.652      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.54G      1.412      1.382      1.591         73        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.8s
#                    all        360        854      0.556      0.641      0.659      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.54G      1.399       1.39      1.604         77        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.5s
#                    all        360        854      0.511      0.671      0.654      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.54G      1.364      1.361      1.581         74        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.541      0.655      0.643      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.54G      1.392      1.347       1.57         71        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854      0.605      0.598      0.635      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.54G      1.405       1.38       1.58         73        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.606      0.608       0.67       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.54G      1.381      1.342      1.576         85        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        360        854      0.615      0.615      0.648      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.54G      1.368      1.333       1.57        112        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.1s
#                    all        360        854      0.561      0.633      0.654      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.54G      1.375      1.312      1.568         65        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.0s
#                    all        360        854      0.537      0.668      0.641      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.54G      1.385      1.353      1.597         80        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.561      0.659       0.66      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.54G      1.384       1.36      1.583         80        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.3s
#                    all        360        854       0.56      0.636      0.638      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.54G      1.351      1.303      1.556         63        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s
#                    all        360        854      0.501      0.603      0.609      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.54G      1.353      1.308      1.556         72        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        360        854      0.557      0.616       0.64      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      4.54G      1.357      1.344      1.568         70        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.1s
#                    all        360        854      0.627      0.583       0.67      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.54G      1.374      1.312       1.57         78        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.4s
#                    all        360        854      0.622      0.651      0.674       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.54G      1.336      1.275      1.545         85        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.0s
#                    all        360        854       0.63      0.663      0.701      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.54G      1.348      1.278      1.556         73        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.569      0.677      0.667      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      4.54G      1.349      1.342      1.554         79        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.1s
#                    all        360        854      0.581      0.653      0.682      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.54G       1.35      1.303      1.552         68        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 3.9s
#                    all        360        854      0.641      0.658      0.708      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.54G      1.328      1.264      1.528         70        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.3s
#                    all        360        854      0.658       0.65        0.7       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.54G      1.343      1.289      1.555         75        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.2s
#                    all        360        854      0.554      0.632       0.65      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.54G       1.32      1.255      1.536         75        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 3.9s
#                    all        360        854      0.629      0.646      0.705      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.54G      1.334      1.261      1.538         51        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 4.9s
#                    all        360        854      0.608      0.649      0.674      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.54G      1.333      1.264       1.54         77        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.592      0.689      0.712      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.54G      1.321      1.255      1.534         72        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.5s
#                    all        360        854      0.592      0.664      0.698      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.54G      1.303      1.232      1.523         72        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.617      0.676      0.701       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.54G      1.316      1.232      1.529         67        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854      0.551      0.664      0.653      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      4.54G      1.292      1.208      1.515         59        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s
#                    all        360        854      0.617      0.638      0.692      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      4.54G      1.308      1.219      1.525         76        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.1s
#                    all        360        854      0.592      0.652      0.677      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.54G      1.278      1.222      1.506         83        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        360        854      0.595      0.685      0.711      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.54G      1.294      1.203      1.515         79        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.681      0.647      0.711      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.54G      1.284      1.201      1.511         80        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        360        854       0.67      0.623      0.699      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.54G      1.286      1.189      1.522         71        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.619      0.655      0.688      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.54G      1.283      1.215      1.515         74        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.2s
#                    all        360        854      0.562      0.663      0.663      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.54G      1.269      1.179      1.503         74        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.672      0.661       0.71       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.54G      1.267      1.174      1.497         65        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.2s
#                    all        360        854      0.641      0.651      0.703      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.54G      1.269      1.166      1.496         87        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854       0.64      0.652      0.684      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.54G       1.26       1.17      1.478         79        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.4s
#                    all        360        854      0.607       0.66      0.692      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.54G      1.259      1.145      1.489         62        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.7s
#                    all        360        854      0.568      0.688       0.69      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.54G      1.264      1.153      1.487         86        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 3.9s
#                    all        360        854      0.638      0.645      0.702      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.54G      1.273      1.161      1.494         74        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.3s
#                    all        360        854      0.625      0.655      0.699      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.54G      1.268      1.175      1.492         67        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.695      0.647      0.707      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.54G       1.26      1.153      1.486         77        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        360        854      0.671      0.651      0.691      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.54G      1.251       1.15      1.481         69        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.621      0.664      0.696      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.54G      1.241      1.138      1.481         80        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.663      0.634      0.703      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.54G       1.25      1.131      1.483         70        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 5.1s
#                    all        360        854      0.675      0.665      0.715      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.54G      1.231      1.124      1.464         75        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.656       0.67      0.722      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.54G      1.263      1.137      1.487         77        640: 100% ━━━━━━━━━━━━ 90/90 2.6it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.7it/s 4.5s
#                    all        360        854      0.632      0.706      0.733      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.54G      1.224      1.093      1.472         81        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.4it/s 4.9s
#                    all        360        854      0.635      0.674       0.72      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.54G      1.233      1.101      1.469         77        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.655      0.662      0.709      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.54G      1.216      1.088      1.455         67        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854       0.66      0.672      0.718      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.54G      1.237      1.103      1.465         51        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.8s
#                    all        360        854       0.66       0.66      0.721      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.54G      1.223      1.094       1.46         73        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 31.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854      0.628      0.679      0.715      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.54G      1.208      1.097      1.459         59        640: 100% ━━━━━━━━━━━━ 90/90 2.9it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.5s
#                    all        360        854      0.729      0.639      0.735      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.54G      1.214      1.079      1.455         58        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 32.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854       0.65      0.692      0.736      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.54G      1.214      1.086      1.448         87        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.2it/s 5.4s
#                    all        360        854      0.681      0.671      0.742      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.54G      1.211       1.07      1.441         79        640: 100% ━━━━━━━━━━━━ 90/90 2.8it/s 31.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s
#                    all        360        854       0.69      0.652       0.73      0.385
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.54G       1.23      1.016      1.498         29        640: 100% ━━━━━━━━━━━━ 90/90 2.7it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.5s
#                    all        360        854      0.623      0.687      0.693      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.54G      1.216     0.9609      1.495         40        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.1it/s 3.9s
#                    all        360        854      0.642      0.675      0.699      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.54G      1.208      0.956      1.498         36        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        360        854       0.63      0.671      0.708      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.54G      1.178     0.9439      1.484         44        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.7s
#                    all        360        854      0.645       0.66      0.719      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.54G      1.206      0.932        1.5         40        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.629      0.668      0.702      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.54G      1.184     0.9307      1.479         34        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.3s
#                    all        360        854      0.652      0.667      0.712      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.54G      1.178     0.9236      1.483         42        640: 100% ━━━━━━━━━━━━ 90/90 3.1it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.6it/s 4.6s
#                    all        360        854      0.626      0.682      0.701      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.54G      1.167     0.9111      1.466         41        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.1s
#                    all        360        854      0.657      0.671      0.709      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.54G      1.167     0.9242      1.473         41        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.7s
#                    all        360        854      0.661      0.666      0.699      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.54G      1.178     0.9127      1.483         32        640: 100% ━━━━━━━━━━━━ 90/90 3.0it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.5it/s 4.7s
#                    all        360        854      0.654       0.68      0.702      0.367
#
# 100 epochs completed in 1.178 hours.
# Optimizer stripped from /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2/weights/last.pt, 22.5MB
# Optimizer stripped from /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2/weights/best.pt, 22.5MB
#
# Validating /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2/weights/best.pt...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.3it/s 5.1s
#                    all        360        854      0.726       0.64      0.736      0.388
#                crazing         60        162      0.743      0.286      0.539      0.234
#              inclusion         71        159      0.716      0.717      0.798      0.462
#                patches         73        193      0.846      0.839      0.914        0.6
#         pitted_surface         60         87      0.802      0.713      0.819      0.412
#        rolled-in_scale         60        132      0.648      0.424      0.518      0.195
#              scratches         60        121      0.598       0.86      0.826      0.423
# Speed: 0.2ms preprocess, 4.9ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to /content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2

# %%
from google.colab import files
files.download('/content/drive/MyDrive/defect-detection/runs/detect/steel_defect_v2/weights/best.pt')
